# %%
import torch
import torch.nn as nn
import numpy as np

class ResidualUnit(nn.Module):
    def __init__(self, in_channels, use_bn = False):
        super().__init__()
        self.use_bn = use_bn
        if self.use_bn:
            self.bn1 = nn.BatchNorm2d(in_channels)
            self.bn2 = nn.BatchNorm2d(in_channels)    
        self.conv1 = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1, bias=True)
        self.conv2 = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1, bias=True)
        self.relu1 = nn.ReLU()
        self.relu2 = nn.ReLU() # maybe not be required

    def forward(self, x):
        residual = x
        out = x
        if self.use_bn:
            out = self.bn1(x)
        out = self.relu1(out)
        out = self.conv1(out)
        if self.use_bn:
            out = self.bn2(out)
        out = self.relu2(out)
        out = self.conv2(out)
        out += residual
        return out

class ResidualPipeline(nn.Module):
    def __init__(self, in_channels, n_units, use_bn = False):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, 64, kernel_size=3, stride=1, padding=1, bias=True)
        self.conv2 = nn.Conv2d(64, 2, kernel_size=3, stride=1, padding=1, bias=True)
        layers = []
        for i in range(n_units):
            layers.append(ResidualUnit(64, use_bn))
        self.resnet_stack = nn.Sequential(*layers)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.resnet_stack(x)
        x = self.relu(x) # not there in original paper
        x = self.conv2(x)
        return x

class ExternalEncoder(nn.Module):
    def __init__(self, ext_dim, map_dim):
        super().__init__()
        self.map_dim = map_dim
        self.fcc1 = nn.Linear(ext_dim, 64, bias = True)
        self.fcc2 = nn.Linear(64, np.prod(map_dim), bias = True)
        self.relu1 = nn.ReLU()
        self.relu2 = nn.ReLU() # maybe not be required
        
    def forward(self, x):
        x = self.fcc1(x)
        x = self.relu1(x)
        x = self.fcc2(x)
        x = self.relu2(x)
        return x.view(-1, *self.map_dim)
    
class STResnet(nn.Module):
    def __init__(self, c_channel, p_channel, t_channel, n_residual_units, ext_dim, map_dim, use_bn = False):
        super().__init__()
        self.e_pipe = ExternalEncoder(ext_dim, map_dim)
        self.c_pipe = ResidualPipeline(c_channel, n_residual_units, use_bn)
        self.p_pipe = ResidualPipeline(p_channel, n_residual_units, use_bn)
        self.t_pipe = ResidualPipeline(t_channel, n_residual_units, use_bn)
        # 1 dimension for batch processing, this class cannot process unbatched data
        self.w_c = nn.Parameter(torch.randn(1, *map_dim))
        self.w_p = nn.Parameter(torch.randn(1, *map_dim))
        self.w_t = nn.Parameter(torch.randn(1, *map_dim))
        self.tanh = nn.Tanh()
        
    def forward(self, x_c, x_p, x_t, x_e):
        y_e = self.e_pipe(x_e)
        y_c = self.c_pipe(x_c)
        y_p = self.p_pipe(x_p)
        y_t = self.t_pipe(x_t)
        # Fusion: Eliment wise product (Hadamard Product)
        y = self.w_c*y_c + self.w_p*y_p + self.w_t*y_t
        y = self.tanh(y+y_e)
        return y

modelpath = './checkpoints/TaxiBJ/k_fold_stresnet.pt'
if not torch.cuda.is_available():
    model = torch.load(modelpath, map_location=torch.device('cpu'))
else:
    model = torch.load(modelpath, map_location=torch.device('cuda'))
    torch.cuda.get_device_name(0)
model.eval();

# %%
# August 10 to 12, 2013 inflow
startdate = '2013-08-10'
dateindex = 0
days = []
flow = np.load('./Datasets/TaxiBJ/TaxiBJ2013.npy')
with open('./Datasets/TaxiBJ/days2013.txt', 'r') as f:
    lines = f.readlines()
    for i in range(len(lines)):
        line = lines[i].strip().split(',')
        if line[0] == startdate:
            dateindex = i
        days.append(line)

# chosen grid
gridx, gridy = 11, 11

start = dateindex*48
end = dateindex*48+3*48

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from TaxiBJ import TaxiBJDataset

n_closeness = 4 # 4*30 minutes
n_period = 1 # 1 day
n_trend = 1 # 1 week
taxibj_dataset_test = TaxiBJDataset('./Datasets/TaxiBJ/',n_closeness,n_period,n_trend,0.001,False)
mmn = taxibj_dataset_test.mmn_flow
# Out:
# min: 0.0 max: 1292.0
# min: -15.1 max: 36.1
# min: 0.0 max: 31.32

# %%
# get original data for August 10 to 12, 2013 inflow
in_flow = flow[start:end, 0, gridx, gridy]

foundstart, foundend = -1, -1
for i in range(len(taxibj_dataset_test)):
    if foundstart != -1:
        i = foundstart + (end - start)
    x_c, x_p, x_t, x_e, y = taxibj_dataset_test[i]
    flow_org = np.zeros((1, 2, 32, 32))
    flow_org[0,:,:,:] = mmn.inverse_transform(y).cpu().detach().numpy()[:,:,:]
    compare = np.around(np.squeeze(flow_org, axis=0))
    if np.array_equal(compare, flow[start]): # if equal to August 10, 2013 data
        print('start found at i = ' + str(i))
        foundstart = i
    if np.array_equal(compare, flow[end]): # if equal to August 12, 2013 data
        print('end found at i = ' + str(i))
        foundend = i
        break

# get model predicted data for August 10 to 12, 2013 inflow
pred_in_flow = np.zeros((foundend-foundstart,))
for i in range(foundstart, foundend):
    x_c, x_p, x_t, x_e, _ = taxibj_dataset_test[i]
    x_e = torch.unsqueeze(x_e, 0)
    x_c = torch.unsqueeze(x_c, 0)
    x_p = torch.unsqueeze(x_p, 0)
    x_t = torch.unsqueeze(x_t, 0)
    y_pred = model(x_c, x_p, x_t, x_e)
    flow_pred = np.zeros((1, 2, 32, 32))
    flow_pred[0,:,:,:] = mmn.inverse_transform(y_pred).cpu().detach().numpy()[:,:,:]
    pred_in_flow[i-foundstart] = flow_pred[0, 0, gridx, gridy]
# Out:
# start found at i = 1100
# end found at i = 1244

# %%
# get t step prediction data for August 10 to 12, 2013 inflow
tstep_data1 = np.load('../Datasets/TaxiBJ_1_step.npy')
# tstep_data1 = mmn.inverse_transform(tstep_data1) # forgot to inverse_transform

tstep_data2 = np.load('../Datasets/TaxiBJ_2_step.npy')
# tstep_data2 = mmn.inverse_transform(tstep_data2) # forgot to inverse_transform

tstep_data3 = np.load('../Datasets/TaxiBJ_3_step.npy')
# tstep_data3 = mmn.inverse_transform(tstep_data3) # forgot to inverse_transform

tstep_data4 = np.load('../Datasets/TaxiBJ_4_step.npy')
# tstep_data4 = mmn.inverse_transform(tstep_data4) # forgot to inverse_transform

tstep1_in_flow = np.zeros((foundend-foundstart,))
tstep2_in_flow = np.zeros((foundend-foundstart,))
tstep3_in_flow = np.zeros((foundend-foundstart,))
tstep4_in_flow = np.zeros((foundend-foundstart,))
for j in range(1,5):
    for i in range(foundstart, foundend):
        eval(f'tstep{j}_in_flow')[i-foundstart] = eval(f'tstep_data{j}')[i-j, 0, 0, gridx, gridy]

# %%
InteractiveShell.ast_node_interactivity = "last_expr"

# %%
# visualize data inflow comparison here
import matplotlib.pyplot as plt

t = 4
fig = plt.figure()
# fig.set_size_inches(6.4, 4.8) default
fig.set_size_inches(8, 6)
time = np.linspace(1, 3*48, num=3*48)
plt.plot(time, in_flow, label='real inflow', color='red')
plt.plot(time, pred_in_flow, label='predicted inflow', color='blue')
plt.plot(time, eval(f'tstep{t}_in_flow'), label=f'{t}-step prediction inflow', color='green')
graphdays = [weekday for date, weekday in days[dateindex:dateindex+3]]
plt.xticks(np.linspace(24, 2*48+24, num=3), graphdays)
plt.title(f'Inflow in a busy Beijing area ({gridx}, {gridy}) from August 10, 2013 to August 12, 2013')
plt.ylabel('Inflow')
plt.legend(loc='best')
plt.show()

# %%
# visualize data inflow comparison here

fig = plt.figure()
# fig.set_size_inches(6.4, 4.8) default
fig.set_size_inches(8, 6)
time = np.linspace(1, 3*48, num=3*48)
plt.plot(time, pred_in_flow, label='1-step prediction inflow', color='black')
plt.plot(time, tstep2_in_flow, label='2-step prediction inflow', color='green')
plt.plot(time, tstep3_in_flow, label=f'3-step prediction inflow', color='red')
plt.plot(time, tstep4_in_flow, label=f'4-step prediction inflow', color='blue')
graphdays = [weekday for date, weekday in days[dateindex:dateindex+3]]
plt.xticks(np.linspace(24, 2*48+24, num=3), graphdays)
plt.title(f'Inflow in a busy Beijing area ({gridx}, {gridy}) from August 10, 2013 to August 12, 2013')
plt.ylabel('Inflow')
plt.legend(loc='best')
plt.show()

# %%
# February 8 to 14, 2016 inflow
startdate = '2016-02-15'
dateindex = 0
days = []
flow = np.load('./Datasets/TaxiBJ/TaxiBJ2016_1.npy')
flow = np.vstack([flow, np.load('./Datasets/TaxiBJ/TaxiBJ2016_2.npy')])

with open('./Datasets/TaxiBJ/days2016.txt', 'r') as f:
    lines = f.readlines()
    for i in range(len(lines)):
        line = lines[i].strip().split(',')
        if line[0] == startdate:
            dateindex = i
        days.append(line)

# chosen grid
gridx, gridy = 11, 11

start = dateindex*48
end = dateindex*48+7*48

# %%
in_flow = flow[start:end, 0, gridx, gridy]

foundstart, foundend = -1, -1
for i in range(len(taxibj_dataset_test)):
    if foundstart != -1:
        i = foundstart + (end - start)
    x_c, x_p, x_t, x_e, y = taxibj_dataset_test[i]
    flow_org = np.zeros((1, 2, 32, 32))
    flow_org[0,:,:,:] = mmn.inverse_transform(y).cpu().detach().numpy()[:,:,:]
    compare = np.around(np.squeeze(flow_org, axis=0))
    if np.array_equal(compare, flow[start]):
        print('start found at i = ' + str(i))
        foundstart = i
    if np.array_equal(compare, flow[end]):
        print('end found at i = ' + str(i))
        foundend = i
        break

pred_in_flow = np.zeros((foundend-foundstart,))
for i in range(foundstart, foundend):
    x_c, x_p, x_t, x_e, _ = taxibj_dataset_test[i]
    x_e = torch.unsqueeze(x_e, 0)
    x_c = torch.unsqueeze(x_c, 0)
    x_p = torch.unsqueeze(x_p, 0)
    x_t = torch.unsqueeze(x_t, 0)
    y_pred = model(x_c, x_p, x_t, x_e)
    flow_pred = np.zeros((1, 2, 32, 32))
    flow_pred[0,:,:,:] = mmn.inverse_transform(y_pred).cpu().detach().numpy()[:,:,:]
    pred_in_flow[i-foundstart] = flow_pred[0, 0, gridx, gridy]
# Out:
# start found at i = 17501
# end found at i = 17837

# %%
tstep1_in_flow = np.zeros((foundend-foundstart,))
tstep2_in_flow = np.zeros((foundend-foundstart,))
tstep3_in_flow = np.zeros((foundend-foundstart,))
tstep4_in_flow = np.zeros((foundend-foundstart,))
for j in range(1,5):
    for i in range(foundstart, foundend):
        eval(f'tstep{j}_in_flow')[i-foundstart] = eval(f'tstep_data{j}')[i-j, 0, 0, gridx, gridy]

# %%
# visualize data inflow comparison here

t = 1
fig = plt.figure()
# fig.set_size_inches(6.4, 4.8) default
fig.set_size_inches(8, 6)
time = np.linspace(1, 7*48, num=7*48)
plt.plot(time, in_flow, label='real inflow', color='red')
plt.plot(time, pred_in_flow, label='predicted inflow', color='blue')
# plt.plot(time, eval(f'tstep{t}_in_flow'), label=f'{t}-step prediction inflow', color='green')
graphdays = [weekday for date, weekday in days[dateindex:dateindex+7]]
plt.xticks(np.linspace(24, 6*48+24, num=7), graphdays)
plt.title(f'Inflow in a Beijing area ({gridx}, {gridy}) During Non-holidays (February 15 to 21, 2016)')
plt.ylabel('Inflow')
plt.legend(loc='best')
plt.show()
